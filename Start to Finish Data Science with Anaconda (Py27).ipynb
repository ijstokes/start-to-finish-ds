# %% [markdown]
# Start to Finish Data Science with Anaconda
# =======================
# *Python 2.7 Version*
# -------------------

# %% [markdown]
# Data science is about a systematic way to apply numerical and visual techniques to analyze and interpret data.  To do that you need easy access to the best numerical computing, data processing, and visualization tools today.

# %% [markdown]
# <center>
# <img src=https://s3.amazonaws.com/ijstokes-public/cio/img/Anaconda_stacked_RGB.png width=400 />
# </center>

# %% [markdown]
# This material is part of a 60 minute workshop introducing you to Anaconda: your gateway to a rich ecosystem of open source data science tools and libraries.

# %% [markdown]
# With [Anaconda](http://anaconda.com/downloads) installed you can use Navigator to start a Jupyter Notebook session and get started right away, which is exactly what we're going to do.
#
# This short workshop shows how easy it is to perform key aspects of the data science workflow:
#
# * data injest
# * data manipulation
# * data visualization
# * data analysis
# * data modeling
#
# You aren't expected to follow exactly every step.  But this should help motivate you to see how much can be achieved with the exciting world of Open Data Science using the Anaconda platform.

# %% [markdown]
# Navigate to the Anaconda Cloud page for this asset which can be found at:
#
# <p>
# <font size="+1">
# [http://anaconda.org/ijstokes/data-science-with-anaconda](http://anaconda.org/ijstokes/data-science-with-anaconda)
# </font>
# </p>
#
# Anaconda Cloud provides a public instance of Anaconda Repository.  That particular asset has been published in the `ijstokes` channel as a publicly accessible Jupyter Notebook.  From there you can download a template version of the Notebook that will allow you to follow along.

# %% [markdown]
# Anaconda Navigator and Jupyter Notebooks
# --------------------------------------
#
# Start Anaconda Navigator and click the *"Launch"* button to start Jupyter Notebook:
#
# ![Anaconda Navigator](https://ijstokes-public.s3.amazonaws.com/cio/img/NavigatorScreenshot.png)

# %% [markdown]
# ### Open Data Science = Your Toolbox, Your Tools
#
# Anaconda hands you a pretty well stocked tool box for Open Data Science, but more importantly it gives you agility to work quickly and easily on many different problems, and flexibility to customize the tools you have on hand through the Conda package management system.
#
# Windows, Mac, and Linux: everyone can work from the same starting point.  No administrator rights required, no interfering with software and tools you already have installed.

# %% [markdown]
# Jupyter basics
# ------------------------------------------
#
# More tips under the *Help* menu entry *Keyboard shortcuts*
#
# * Cells
# * Execute
#     * `SHIFT-ENTER` to execute a cell and go to the next cell
#     * `CTRL-ENTER` to execute a cell but keep focus on the same cell
#     * `ALT-ENTER` to execute a cell and insert a new cell after it
# * Stop
# * Insert new cell
# * Re-order cells
# * Clear output
# * Restart kernel

# %%
s = 'hello'
t = 'world'

# %%
u = s + t

# %%
u
# Out:
# 'helloworld'

# %%
a = 3
b = 7
c = a + b

# %%
c
# Out:
# 10

# %% [markdown]
# Injest, analyze, and clean data with Pandas
# -----------------------------------------
# <center>
# <img src=http://pandas.pydata.org/_static/pandas_logo.png />
# </center>
# Reference: [Pandas documentation](http://pandas.pydata.org)

# %% [markdown]
# ### Get Your Hands Dirty, and Code First
#
# Once upon a time the coding part was complicated, time consuming, and only possible by experts who were often far removed from the line-of-business objectives they are trying to serve.  Today you need to move beyond spreadsheets for data insights and need to be empowered to find answers yourself, with little or no reference to a distant analytics team.
#
# Anaconda was created to empower anyone who can use Excel to have in their hands the tools they need to injest data, analyze it, visualize it, build interactive apps, and deploy production analysis models at scale.
#
# So I will start by demonstrating a simple analysis workflow of a well known sample data set of 400 cars from the 1970s.

# %%
import pandas as pd

pd.set_option("display.max_rows",10)

# %% [markdown]
# Normally we wouldn't read data this way, but this is some sample data that is bundled with Bokeh for convenience

# %%
from bokeh.sampledata.autompg import autompg

# %% [markdown]
# In Python just typing the name of a variable will show you a "representation" of that variable. In the case of a `pandas.DataFrame` we'll see a data table.

# %%
type(autompg)
# Out:
# pandas.core.frame.DataFrame

# %%
autompg
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# 389              dodge rampage
# 390                ford ranger
# 391                 chevy s-10
#
# [392 rows x 9 columns]

# %% [markdown]
# Look at the data, sorted by fuel efficiency dimension `mpg`

# %%
autompg.sort_values(by='mpg')
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin                  name
# 28    9.0    8  304.0  193    4732   18.5  70       1              hi 1200d
# 26   10.0    8  307.0  200    4376   15.0  70       1             chevy c20
# 25   10.0    8  360.0  215    4615   14.0  70       1             ford f250
# 27   11.0    8  318.0  210    4382   13.5  70       1            dodge d200
# 123  11.0    8  350.0  180    3664   11.0  73       1      oldsmobile omega
# ..    ...  ...    ...  ...     ...    ...  ..     ...                   ...
# 324  43.4    4   90.0   48    2335   23.7  80       2    vw dasher (diesel)
# 388  44.0    4   97.0   52    2130   24.6  82       2             vw pickup
# 323  44.3    4   90.0   48    2085   21.7  80       2  vw rabbit c (diesel)
# 327  44.6    4   91.0   67    1850   13.8  80       3   honda civic 1500 gl
# 320  46.6    4   86.0   65    2110   17.9  80       3             mazda glc
#
# [392 rows x 9 columns]

# %% [markdown]
# Notice the first word in each name entry is the *make*.  We'll use this to add a `make` field to the `pandas.DataFrame` object:

# %%
autompg.name
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 387              ford mustang gl
# 388                    vw pickup
# 389                dodge rampage
# 390                  ford ranger
# 391                   chevy s-10
# Name: name, Length: 392, dtype: object

# %%
n = autompg.name[0]

# %%
n
# Out:
# 'chevrolet chevelle malibu'

# %%
n.split()
# Out:
# ['chevrolet', 'chevelle', 'malibu']

# %%
parts = n.split()

# %%
parts
# Out:
# ['chevrolet', 'chevelle', 'malibu']

# %%
parts[0]
# Out:
# 'chevrolet'

# %%
autompg
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# 389              dodge rampage
# 390                ford ranger
# 391                 chevy s-10
#
# [392 rows x 9 columns]

# %%
autompg['make'] = pd.Series((n.split()[0] for n in autompg.name), 
                            index=autompg.index)

# %% [markdown]
# Let's look at a sorted list of this new dimension

# %%
autompg
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                           name       make
# 0    chevrolet chevelle malibu  chevrolet
# 1            buick skylark 320      buick
# 2           plymouth satellite   plymouth
# 3                amc rebel sst        amc
# 4                  ford torino       ford
# ..                         ...        ...
# 387            ford mustang gl       ford
# 388                  vw pickup         vw
# 389              dodge rampage      dodge
# 390                ford ranger       ford
# 391                 chevy s-10      chevy
#
# [392 rows x 10 columns]

# %%
sorted(autompg.make.unique())
# Out:
# ['amc',
#  'audi',
#  'bmw',
#  'buick',
#  'cadillac',
#  'capri',
#  'chevroelt',
#  'chevrolet',
#  'chevy',
#  'chrysler',
#  'datsun',
#  'dodge',
#  'fiat',
#  'ford',
#  'hi',
#  'honda',
#  'maxda',
#  'mazda',
#  'mercedes',
#  'mercedes-benz',
#  'mercury',
#  'nissan',
#  'oldsmobile',
#  'opel',
#  'peugeot',
#  'plymouth',
#  'pontiac',
#  'renault',
#  'saab',
#  'subaru',
#  'toyota',
#  'toyouta',
#  'triumph',
#  'vokswagen',
#  'volkswagen',
#  'volvo',
#  'vw']

# %% [markdown]
# Several makes have spelling errors or inconsistencies. Pandas can help us fix those in place:

# %%
autompg.loc[autompg.make == 'chevroelt', 'make'] = 'chevrolet'
autompg.loc[autompg.make == 'chevy',     'make'] = 'chevrolet'
autompg.loc[autompg.make == 'maxda',     'make'] = 'mazda'
autompg.loc[autompg.make == 'mercedes',  'make'] = 'mercedes-benz'
autompg.loc[autompg.make == 'toyouta',   'make'] = 'toyota'
autompg.loc[autompg.make == 'vokswagen', 'make'] = 'volkswagen'
autompg.loc[autompg.make == 'vw',        'make'] = 'volkswagen'

# %%
# Litres per 100 km
autompg['L100'] = pd.Series(((100*3.78)/(1.61*m) for m in autompg.mpg), 
                            index=autompg.index)

# %%
# convert integer region of origin into a string
autompg['origin'] = autompg['origin'].astype('category')
autompg.origin = autompg.origin.cat.rename_categories('American European Asian'.split())

# %%
# F = mass * acceleration, here 'accel' = seconds for 0-60 mi/hr
# so actual acceleration is inversely related to the 'accel' value
autompg['force'] = pd.Series((row.weight/row.accel for idx, row in autompg.iterrows()),
                             index=autompg.index)

# %%
autompg
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr    origin  \
# 0    18.0    8  307.0  130    3504   12.0  70  American
# 1    15.0    8  350.0  165    3693   11.5  70  American
# 2    18.0    8  318.0  150    3436   11.0  70  American
# 3    16.0    8  304.0  150    3433   12.0  70  American
# 4    17.0    8  302.0  140    3449   10.5  70  American
# ..    ...  ...    ...  ...     ...    ...  ..       ...
# 387  27.0    4  140.0   86    2790   15.6  82  American
# 388  44.0    4   97.0   52    2130   24.6  82  European
# 389  32.0    4  135.0   84    2295   11.6  82  American
# 390  28.0    4  120.0   79    2625   18.6  82  American
# 391  31.0    4  119.0   82    2720   19.4  82  American
#
#                           name        make       L100       force
# 0    chevrolet chevelle malibu   chevrolet  13.043478  292.000000
# 1            buick skylark 320       buick  15.652174  321.130435
# 2           plymouth satellite    plymouth  13.043478  312.363636
# 3                amc rebel sst         amc  14.673913  286.083333
# 4                  ford torino        ford  13.810742  328.476190
# ..                         ...         ...        ...         ...
# 387            ford mustang gl        ford   8.695652  178.846154
# 388                  vw pickup  volkswagen   5.335968   86.585366
# 389              dodge rampage       dodge   7.336957  197.844828
# 390                ford ranger        ford   8.385093  141.129032
# 391                 chevy s-10   chevrolet   7.573633  140.206186
#
# [392 rows x 12 columns]

# %%
sorted(autompg.make.unique())
# Out:
# ['amc',
#  'audi',
#  'bmw',
#  'buick',
#  'cadillac',
#  'capri',
#  'chevrolet',
#  'chrysler',
#  'datsun',
#  'dodge',
#  'fiat',
#  'ford',
#  'hi',
#  'honda',
#  'mazda',
#  'mercedes-benz',
#  'mercury',
#  'nissan',
#  'oldsmobile',
#  'opel',
#  'peugeot',
#  'plymouth',
#  'pontiac',
#  'renault',
#  'saab',
#  'subaru',
#  'toyota',
#  'triumph',
#  'volkswagen',
#  'volvo']

# %%
with pd.option_context('display.max_rows', 999):
    print(autompg.groupby('make').size())
# Out:
# make
# amc              27
# audi              7
# bmw               2
# buick            17
# cadillac          2
# capri             1
# chevrolet        47
# chrysler          6
# datsun           23
# dodge            28
# fiat              8
# ford             48
# hi                1
# honda            13
# mazda            12
# mercedes-benz     3
# mercury          11
# nissan            1
# oldsmobile       10
# opel              4
# peugeot           8
# plymouth         31
# pontiac          16
# renault           3
# saab              4
# subaru            4
# toyota           26
# triumph           1
# volkswagen       22
# volvo             6
# dtype: int64

# %% [markdown]
# Visualize data with Bokeh
# -----------------------
# <center>
# <img src=https://bokeh.github.io/images/logo.svg />
# </center>
# Reference: [Bokeh documentation](http://bokeh.pydata.org)

# %%
#from bkcharts import Scatter, Histogram

# %%
from bokeh.charts import Scatter, Histogram
from bokeh.models import HoverTool
from bokeh.io     import output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="16a736d9-19d8-47e4-adaf-09817114b76f">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# What trend do we observe in this data set?
# What was happening through the 1970s that might cause this?

# %%
s = Scatter(data=autompg, x='yr', y='mpg', color='origin', height=300)
show(s)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b4145183-5c32-464c-b998-375838280d9d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b4145183-5c32-464c-b998-375838280d9d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b4145183-5c32-464c-b998-375838280d9d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b4145183-5c32-464c-b998-375838280d9d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a57f42da-b19c-47f7-b68e-aa4828e7765c":{"roots":{"references":[{"attributes":{},"id":"211d7862-00fb-4792-8f32-faea65c36ed1","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"European"},"renderers":[{"id":"515c4322-8473-4c3a-9bf9-f1cb73e067ad","type":"GlyphRenderer"}]},"id":"7f242e8a-3b1e-4051-952f-1267d3ef202f","type":"LegendItem"},{"attributes":{"label":{"value":"Asian"},"renderers":[{"id":"c4884864-ad1b-45b6-8bd8-84d3498af21e","type":"GlyphRenderer"}]},"id":"73b66d4e-710f-4eed-9286-d9019d1fc34a","type":"LegendItem"},{"attributes":{},"id":"2bbbeb73-3326-4b95-b506-192d4542af73","type":"BasicTicker"},{"attributes":{"axis_label":"mpg","formatter":{"id":"211d7862-00fb-4792-8f32-faea65c36ed1","type":"BasicTickFormatter"},"plot":{"id":"e8c0471f-5033-4ce9-a77a-7f8f78c90743","subtype":"Chart","type":"Plot"},"ticker":{"id":"dc127493-bf45-43ae-beb3-0b8093e486ad","type":"BasicTicker"}},"id":"6f3fa1ec-aae4-4fa4-818b-c53f665619c3","type":"LinearAxis"},{"attributes":{},"id":"e06a1827-9820-4541-a3f3-3946fc5a47a7","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"American"},"renderers":[{"id":"9b177992-176e-4f16-8042-10c5266c924e","type":"GlyphRenderer"}]},"id":"9b781db7-ebad-4ce5-af7b-1b6b2e9b2c54","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"}],"origin":["Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian"],"x_values":[70,70,71,71,71,71,72,72,72,72,72,73,73,73,73,74,74,74,74,74,74,75,75,75,75,76,76,76,76,77,77,77,77,77,77,78,78,78,78,78,78,78,78,79,79,80,80,80,80,80,80,80,80,80,80,80,80,80,81,81,81,81,81,81,81,81,81,81,81,81,82,82,82,82,82,82,82,82,82],"y_values":{"__ndarray__":"...","dtype":"float64","shape":[79]}}},"id":"46b6f1ea-8d0f-4c86-8872-5dbd7f8ab9f7","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"e8c0471f-5033-4ce9-a77a-7f8f78c90743","subtype":"Chart ...

# %% [markdown]
# Let's just look at one make from each of the US, Germany, and Japan

# %%
s = Scatter(data=autompg[autompg.make.isin('ford volkswagen honda'.split())],
            x='yr', y='mpg', color='make', height=300)
show(s)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="17ad795e-7413-4789-9df6-7eb14727c4d4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("17ad795e-7413-4789-9df6-7eb14727c4d4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("17ad795e-7413-4789-9df6-7eb14727c4d4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '17ad795e-7413-4789-9df6-7eb14727c4d4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f8eb0fea-ccae-4787-9eb7-0b353cb0e541":{"roots":{"references":[{"attributes":{},"id":"733d45f2-d597-4092-aaaf-2db763c72269","type":"BasicTickFormatter"},{"attributes":{},"id":"16e00d41-5fa0-42ac-bf67-ea9185ad44b3","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"6ca44df7-94ee-42ba-8282-48b12dabd48f","type":"Circle"},{"attributes":{},"id":"3d1e8826-2e24-4b8f-81e0-c18349d2cc5a","type":"BasicTicker"},{"attributes":{"axis_label":"mpg","formatter":{"id":"16e00d41-5fa0-42ac-bf67-ea9185ad44b3","type":"BasicTickFormatter"},"plot":{"id":"74338eac-bd36-4ff7-8a3c-bade6a3100bf","subtype":"Chart","type":"Plot"},"ticker":{"id":"71e1c982-12a4-4480-86a0-56347e1cf175","type":"BasicTicker"}},"id":"4fef917b-57f2-45a0-85ef-97ddf7dbaa0b","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"74338eac-bd36-4ff7-8a3c-bade6a3100bf","subtype":"Chart","type":"Plot"},"ticker":{"id":"71e1c982-12a4-4480-86a0-56347e1cf175","type":"BasicTicker"}},"id":"2373e547-5bf0-4af4-b4c8-96b3b3aa2018","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"}],"make":["volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen"],"x_values":[70,71,72,72,73,74,75,75,76,76,77,77,78,78,79,80,80,80,80,81,82,82],"y_values":{"__ndarray__":"AAAAAAAAOkAAAAAAAAA7QAAAAAAAADdAAAAAAAAANkAAAAAAAAA6QAAAAAAAADpAAAAAAAAAOUAAAAAAAAA9QAAAAAAAAD1AAAAAAACAPUAAAAAAAAA9QAAAAAAAgD5AzczMzMyMRUAAAAAAAIA/QGZmZmZm5j9AAAAAAADAREBmZmZmZiZGQDMzMzMzs0VAzczMzMzMPUAAAAAAAIBAQAAAAAAAAEJAAAAAAAAARkA=","dtype":"float64","shape":[22]}}},"id":"98b1b076-a52a-48fc-904b-35439ff9aff5","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":48.06,"start":6.539999999999999},"id":"b080228e-f951-4593-960a-b941e15c28d1","type":"Range1d"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"}],"make":["ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford"],"x_values":[70,70,70,70,71,71,71,71,72,72,72,72,73,73,73,73,73,74,74,74,75,75,75,75,75,76,76,76,76,76,77,77,77,78,78,78,78,79,79,79 ...

# %% [markdown]
# How did we do that? With a sub-select on the `autompg` object using something called *"fancy indexing"* to select just the rows that have a make that is one of `ford volkswagen honda`.

# %%
['ford', 'volkswagen', 'honda']
# Out:
# ['ford', 'volkswagen', 'honda']

# %%
df = autompg[autompg.make.isin('ford volkswagen honda'.split())]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83 entries, 4 to 390
# Data columns (total 12 columns):
# mpg       83 non-null float64
# cyl       83 non-null int64
# displ     83 non-null float64
# hp        83 non-null int64
# weight    83 non-null int64
# accel     83 non-null float64
# yr        83 non-null int64
# origin    83 non-null category
# name      83 non-null object
# make      83 non-null object
# L100      83 non-null float64
# force     83 non-null float64
# dtypes: category(1), float64(5), int64(4), object(2)
# memory usage: 8.0+ KB

# %% [markdown]
# Use Bokeh to add some simple interactivity

# %%
s = Scatter(data=autompg[autompg.make.isin('ford volkswagen honda'.split())],
            x='yr', y='mpg', color='make',
            height=300, width=600,
            title='Fuel efficiency of selected vehicles from 1970-1982',
            tools='hover, box_zoom, lasso_select, save, reset',
            tooltips = [
              ('Model','@name'),
              ('MPG', '@mpg'),
              ('HP',  '@hp')
            ])

show(s)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b5e8a29c-fc42-4254-b847-78560d9ff997"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b5e8a29c-fc42-4254-b847-78560d9ff997");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b5e8a29c-fc42-4254-b847-78560d9ff997");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b5e8a29c-fc42-4254-b847-78560d9ff997' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"49d035eb-69b3-4f46-900f-6d55f15a3150":{"roots":{"references":[{"attributes":{"data_source":{"id":"9de61088-65c0-4493-80b7-8d18729d7164","type":"ColumnDataSource"},"glyph":{"id":"47b79fb5-9399-4c0b-b474-ba25e6748c48","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"97f64cf9-bba6-4e58-88e5-b68a72e7f9ad","type":"GlyphRenderer"},{"attributes":{"axis_label":"mpg","formatter":{"id":"5fb412bd-6e06-4096-beb7-771c7416a017","type":"BasicTickFormatter"},"plot":{"id":"8511f07a-214d-49e5-b3ee-e0eefa398f6a","subtype":"Chart","type":"Plot"},"ticker":{"id":"e7d2f419-211f-49d2-ad36-cb4f07e69b8e","type":"BasicTicker"}},"id":"8b12f5f9-6765-4a5b-af77-eebd87708f9e","type":"LinearAxis"},{"attributes":{},"id":"7c3bbf93-96ea-40f1-b278-c53f3ab1de3e","type":"BasicTicker"},{"attributes":{"axis_label":"yr","formatter":{"id":"7e37b3e0-64fd-44c3-8862-142faaab64aa","type":"BasicTickFormatter"},"plot":{"id":"8511f07a-214d-49e5-b3ee-e0eefa398f6a","subtype":"Chart","type":"Plot"},"ticker":{"id":"7c3bbf93-96ea-40f1-b278-c53f3ab1de3e","type":"BasicTicker"}},"id":"cc1ad5eb-22e4-4e89-9b83-c0af6b69b730","type":"LinearAxis"},{"attributes":{"plot":{"id":"8511f07a-214d-49e5-b3ee-e0eefa398f6a","subtype":"Chart","type":"Plot"},"ticker":{"id":"7c3bbf93-96ea-40f1-b278-c53f3ab1de3e","type":"BasicTicker"}},"id":"ead6beba-9bda-4b16-95fe-ae6e7dc7670d","type":"Grid"},{"attributes":{},"id":"7e37b3e0-64fd-44c3-8862-142faaab64aa","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x_values","y_values","name","mpg","hp"],"data":{"chart_index":[{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"}],"hp":[97,53,53,68,60,68,67,72,60,75,75,67,67],"make":["honda","honda","honda","honda","honda","honda","honda","honda","honda","honda","honda","honda","honda"],"mpg":{"__ndarray__":"AAAAAAAAOEAAAAAAAIBAQAAAAAAAgEBAAAAAAACAP0DNzMzMzAxCQAAAAAAAgD1AzczMzMxMRkAzMzMzMzNAQM3MzMzMjEFAmpmZmZnZQEAAAAAAAABCQAAAAAAAAENAAAAAAAAAQEA=","dtype":"float64","shape":[13]},"name":["honda civic","honda civic cvcc","honda civic","honda accord cvcc","honda civic cvcc","honda accord lx","honda civic 1500 gl","honda accord","honda civic 1300","honda prelude","honda accord","honda civic","honda civic (auto)"],"x_values":[74,75,76,77,78,78,80,80,81,81,82,82,82],"y_values":{"__ndarray__":"AAAAAAAAOEAAAAAAAIBAQAAAAAAAgEBAAAAAAACAP0DNzMzMzAxCQAAAAAAAgD1AzczMzMxMRkAzMzMzMzNAQM3MzMzMjEFAmpmZmZnZQEAAAAAAAABCQAAAAAAAAENAAAAAAAAAQEA=","dtype":"float64","shape":[13]}}},"id":"6a875e9d-28f1-4c3e-93ed-d0b3b26553e1","type":"ColumnDataSource"},{"attributes":{},"id":"e7d2f419-211f-49d2-ad36-cb4f07e69b8e","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"8511f07a-214d-49e5-b3ee-e0eefa398f6a","subtype":"Chart","type":"Plot"},"ticker":{"id":"e7d2f419-211f-49d2-ad36-cb4f07e69b8e","type":"BasicTicker"}},"id":"e4e365ba-96c4-487a-b6e9-e5a1d5c04562","type":"Grid"},{"attributes":{"callback":null,"plot":{"id":"8511f07a-214d-49e5-b3ee-e0eefa398f6a","subtype":"Chart","type":"Plot"},"tooltips":[["Model","@name"],["MPG","@mpg"],["HP","@hp"]]},"id":"0046a243-b949-4dd2-82c9-cf37d7379c5d","type":"HoverTool"},{"attributes":{"label":{"value":"volkswagen"},"renderers":[{"id":"97f64cf9-bba6-4e58-88e5-b68a72e7f9ad","type":"GlyphRenderer"}]},"id":"3059555d-b0c7-4689-a460-12324bbb76f3","type":"LegendItem"},{"attributes":{"callback":null,"end":48.06,"start":6.539999999999999},"id":"df0daf11-29bb-4a97-97a3-5b0ff76a184f","type":"Range1d"},{"attributes":{},"id":"8f3bbc23-0128-4e5c-853a-7eb696805942","type":"ToolEvents"},{"attributes":{"label":{"value":"ford"},"renderers":[{"id":"9e91f47a-33ed-4871-9314-aa1b43483501","type":"GlyphRenderer"}]},"id":"7be87de4-b5c7-43ab-a522-3520735c139b","type":"LegendItem"},{"attributes":{"overlay":{"id":"302ba378-60ae-46eb-a061-4ad9dad34968","type":"BoxAnnotation"},"plot":{"id":" ...

# %% [markdown]
# Machine Learning and Predictive Models with Scikit-Learn
# -----------------------------------------------------
# <center>
# <img src=http://scikit-learn.org/stable/_images/scikit-learn-logo-notext.png />
# </center>
# Reference: [Scikit-Learn documentation](http://scikit-learn.org/)

# %%
from sklearn.svm          import SVC                    as support_vector_classifier
from sklearn.ensemble     import RandomForestClassifier as random_forest_classifier
from sklearn.neighbors    import KNeighborsClassifier   as knn_classifier
from sklearn.linear_model import LinearRegression       as linear_regression_regressor

from sklearn.cross_validation import train_test_split
# Out:
# /Users/ijstokes/anaconda/envs/ana44clean/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train, test = train_test_split(autompg, train_size=0.80, random_state=123)
train = train.copy()
test  = test.copy()

# %% [markdown]
# ### Linear Regression Model

# %%
model = linear_regression_regressor()
model.fit(train['cyl displ hp weight accel yr'.split()],
          train['mpg'].values.ravel())
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.score(test['cyl displ hp weight accel yr'.split()],
#            test['mpg'].astype(int).values.ravel()) # for discrete predictions
            test['mpg'].values.ravel())              # for continuous predictions
# Out:
# 0.75077542748160853

# %%
predictions = model.predict(test['cyl displ hp weight accel yr'.split()])
predictions
# Out:
# array([ 16.93513471,  31.44386166,  13.92513989,  25.33100232,
#         30.86517173,  16.12912297,  29.84316806,  20.79424901,
#         17.51682663,  33.5962678 ,  15.16484689,  24.05681003,
#         13.43861853,  30.4849891 ,  15.96175622,  22.14058281,
#         29.18249959,   7.26444002,  12.34592112,  14.11414099,
#         22.31888799,  28.78553786,  29.70553983,  35.29035859,
#         34.53708373,  16.04079521,  26.86016519,  31.90293837,
#         22.70010858,  27.39754987,  23.10237142,  31.48471994,
#         17.0945224 ,  20.83682113,  27.73349153,  28.37221631,
#         27.18683665,  27.98877592,  26.11857502,  11.08719175,
#         17.4036681 ,  23.45466615,  25.0567287 ,  21.985068  ,
#         20.55618207,  20.54065738,  28.84321132,  29.74538267,
#         24.29508899,  20.39074464,  20.98390062,  33.4709278 ,
#         16.27399269,  22.37692882,  22.76363708,  14.67741727,
#          7.73764472,  24.38242977,  19.44958426,  30.11714922,
#         16.5131058 ,   6.38634806,  24.59175118,  27.26877553,
#         20.30193067,  33.77916119,  30.9261231 ,  24.59543879,
#         26.23317754,  22.89863311,  25.04347344,  27.96854099,
#         25.57556152,  11.91524446,  26.96353645,  30.35319343,
#         28.79986239,  13.57871975,  21.44849095])

# %%
model.coef_
# Out:
# array([-0.15298156,  0.00129389,  0.03109679, -0.00736309,  0.20276647,
#         0.79566653])

# %%
test['mpg']
# Out:
# 220    17.0
# 245    39.4
# 134    16.0
# 147    24.0
# 390    28.0
#        ...
# 274    21.6
# 318    37.0
# 380    25.0
# 114    15.0
# 189    22.0
# Name: mpg, Length: 79, dtype: float64

# %%
h = Histogram(test.mpg - predictions, height=300)
show(h)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d2dacf61-4e79-4ff9-9c29-84fc2bfbc991"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d2dacf61-4e79-4ff9-9c29-84fc2bfbc991");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d2dacf61-4e79-4ff9-9c29-84fc2bfbc991");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd2dacf61-4e79-4ff9-9c29-84fc2bfbc991' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fa9728bd-46a4-4f6f-a204-806fa501077d":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1c7470b-9b0e-4dc7-94c5-0a5fb68c7273","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2b60d35a-cee7-410e-b7fc-3505f1c4541f","type":"Rect"},{"attributes":{"data_source":{"id":"c097f257-ffe5-494f-9af4-112c8abff0a1","type":"ColumnDataSource"},"glyph":{"id":"2b60d35a-cee7-410e-b7fc-3505f1c4541f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"25f3887c-a637-4a8b-8131-cbd33a50f2ef","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(-2.541674, -0.284107]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[14.0],"label":["(-2.541674, -0.284107]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.257567779627558],"x":["-1.4128905"],"y":[7.0]}},"id":"8dbae54b-fa4c-4082-9ddc-eb2e95e5753d","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(-4.799242, -2.541674]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[18.0],"label":["(-4.799242, -2.541674]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.257567779627558],"x":["-3.670458"],"y":[9.0]}},"id":"c097f257-ffe5-494f-9af4-112c8abff0a1","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"65f9cf2f-5c9d-4a47-9d99-3a0dea1cf805","subtype":"Chart","type":"Plot"}},"id":"2606f49a-bece-4975-a2da-7c618747d621","type":"PanTool"},{"attributes":{},"id":"3abdce2c-27e2-45b5-86d7-412f8899d1d9","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1466f234-825e-4d31-8fd8-5efe77de0533","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"641a810a-cdd5-40a3-9905-f48a80f527e6","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(-0.284107, 1.973461]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[20.0],"label":["(-0.284107, 1.973461]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.257567779627559],"x":["0.8446769999999999"],"y":[10.0]}},"id":"a6ddc75b-ed17-40d1-9d06-1bb7ee1a8d70","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":11.102404939813779,"start":-7.155482939813779},"id":"16286c1f-6980-42b0-b68b-a85610867b50","type":"Range1d"},{"attributes":{},"id":"6be04444-e0e7-4be9-ba66-78894788b1c9","type":"BasicTicker"},{"attributes":{"data_source":{"id":"8dbae54b-fa4c-4082-9ddc-eb2e95e5753d","type":"ColumnDataSource"},"glyph":{"id":"c1c7470b-9b0e-4dc7-94c5-0a5fb68c7273","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"8a68edbf-db27-43af-9e2e-31058f56d00c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(8.746164, 11.003732]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":["(8.746164, 11.003732]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.257567779627559],"x":["9.874948"],"y":[1.5 ...

# %%
delta          = test.mpg - predictions
test['mpg_lr'] = predictions
test['lr']     = delta
test[delta.abs() > 5]
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr    origin  \
# 245  39.4    4   85.0   70    2070   18.6  78     Asian
# 327  44.6    4   91.0   67    1850   13.8  80     Asian
# 273  17.0    6  163.0  125    3140   13.6  78  European
# 240  21.5    4  121.0  110    2600   12.8  77  European
# 307  41.5    4   98.0   76    2144   14.7  80  European
# ..    ...  ...    ...  ...     ...    ...  ..       ...
# 42   13.0    8  400.0  170    4746   12.0  71  American
# 41   12.0    8  383.0  180    4955   11.5  71  American
# 272  20.3    5  131.0  103    2830   15.9  78  European
# 274  21.6    4  121.0  115    2795   15.7  78  European
# 318  37.0    4  119.0   92    2434   15.0  80     Asian
#
#                          name        make       L100       force     mpg_lr  \
# 245            datsun b210 gx      datsun   5.958949  111.290323  31.443862
# 327       honda civic 1500 gl       honda   5.264184  134.057971  33.596268
# 273               volvo 264gl       volvo  13.810742  230.882353  24.056810
# 240                  bmw 320i         bmw  10.920121  203.125000  26.860165
# 307                 vw rabbit  volkswagen   5.657412  145.850340  31.902938
# ..                        ...         ...        ...         ...        ...
# 42   ford country squire (sw)        ford  18.060201  395.500000   7.737645
# 41          dodge monaco (sw)       dodge  19.565217  430.869565   6.386348
# 272                 audi 5000        audi  11.565646  177.987421  26.233178
# 274                saab 99gle        saab  10.869565  178.025478  26.963536
# 318      datsun 510 hatchback      datsun   6.345476  162.266667  30.353193
#
#             lr
# 245   7.956138
# 327  11.003732
# 273  -7.056810
# 240  -5.360165
# 307   9.597062
# ..         ...
# 42    5.262355
# 41    5.613652
# 272  -5.933178
# 274  -5.363536
# 318   6.646807
#
# [16 rows x 14 columns]

# %% [markdown]
# ### Random Forest Classifier

# %%
model = random_forest_classifier(n_estimators=100)
model.fit(train['cyl displ hp weight accel yr'.split()],
          train['mpg'].astype(int).values.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %% [markdown]
# So how does Random Forest compare to Linear Regression?

# %%
model.score(test['cyl displ hp weight accel yr'.split()],
            test['mpg'].astype(int).values.ravel()) # for discrete predictions
#            test['mpg'].values.ravel())              # for continuous predictions
# Out:
# 0.13924050632911392

# %%
predictions = model.predict(test['cyl displ hp weight accel yr'.split()])
predictions
# Out:
# array([15, 31, 14, 23, 31, 18, 23, 17, 15, 36, 16, 20, 15, 30, 15, 19, 24,
#        13, 14, 15, 18, 25, 26, 39, 31, 15, 24, 32, 23, 26, 20, 27, 19, 19,
#        22, 28, 24, 26, 23, 11, 15, 20, 22, 30, 18, 15, 25, 28, 21, 20, 25,
#        32, 16, 20, 20, 16, 13, 28, 18, 33, 16, 13, 24, 20, 17, 39, 34, 20,
#        20, 19, 24, 35, 25, 13, 19, 32, 24, 13, 20])

# %%
delta = test.mpg - predictions
test['mpg_rf'] = predictions
test['rf'] = delta
test[delta.abs() > 5]
# Out:
#       mpg  cyl  displ  hp  weight  accel  yr    origin  \
# 245  39.4    4   85.0  70    2070   18.6  78     Asian
# 327  44.6    4   91.0  67    1850   13.8  80     Asian
# 343  37.0    4   85.0  65    1975   19.4  81     Asian
# 307  41.5    4   98.0  76    2144   14.7  80  European
# 381  38.0    6  262.0  85    3015   17.0  82  American
# 344  37.7    4   89.0  62    2050   17.3  81     Asian
# 329  29.8    4   89.0  62    1845   15.3  80  European
#
#                                   name        make      L100       force  \
# 245                     datsun b210 gx      datsun  5.958949  111.290323
# 327                honda civic 1500 gl       honda  5.264184  134.057971
# 343                     datsun 210 mpg      datsun  6.345476  101.804124
# 307                          vw rabbit  volkswagen  5.657412  145.850340
# 381  oldsmobile cutlass ciera (diesel)  oldsmobile  6.178490  177.352941
# 344                      toyota tercel      toyota  6.227655  118.497110
# 329                   vokswagen rabbit  volkswagen  7.878611  120.588235
#
#         mpg_lr         lr  mpg_rf    rf
# 245  31.443862   7.956138      31   8.4
# 327  33.596268  11.003732      36   8.6
# 343  34.537084   2.462916      31   6.0
# 307  31.902938   9.597062      32   9.5
# 381  27.733492  10.266508      22  16.0
# 344  33.470928   4.229072      32   5.7
# 329  33.779161  -3.979161      39  -9.2

# %%
h = Histogram(delta, height=300)
show(h)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4d0258d4-678c-4396-a190-9d0846dd8c31"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4d0258d4-678c-4396-a190-9d0846dd8c31");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4d0258d4-678c-4396-a190-9d0846dd8c31");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4d0258d4-678c-4396-a190-9d0846dd8c31' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bc9e43cb-f6f7-4367-b374-9ba81fc660aa":{"roots":{"references":[{"attributes":{"data_source":{"id":"56d87435-694b-4cc0-bade-975fdc3cbfec","type":"ColumnDataSource"},"glyph":{"id":"52f87b73-7551-4e08-96a5-12055b21686b","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"c7b75fe2-25e9-419f-895d-8fd590ca0ae3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"57fa1489-2509-4086-b1f4-b9772301df5d","type":"Rect"},{"attributes":{},"id":"c4b4ce15-5c32-49f3-9c72-ee2608f6ab52","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"c8e2f22a-5e32-4f5c-8e4c-a6fddbe818dc","subtype":"Chart","type":"Plot"},"ticker":{"id":"c4b4ce15-5c32-49f3-9c72-ee2608f6ab52","type":"BasicTicker"}},"id":"0d01b7dd-0c86-47ad-817b-1b27f141edda","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["[-9.200000, -7.873684]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["[-9.200000, -7.873684]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.326315789473684],"x":["-8.536842"],"y":[0.5]}},"id":"76277673-7f1e-465b-ba66-4d1ea3566278","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"8889090f-be44-46ea-93a6-9afef8cafbfb","type":"ColumnDataSource"},"glyph":{"id":"0edbd0b2-50f5-46fa-a851-6d5a26d7a163","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"739fa5e4-1ad5-425f-9b2c-1ba6f151ceb4","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c3d12e4d-788b-4800-baa7-e0c96551e54c","type":"ColumnDataSource"},"glyph":{"id":"379a7644-2e73-426c-944c-229e5efb43bf","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"32a148ae-7904-4ccc-af46-5eb8678553e5","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(-5.221053, -3.894737]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(-5.221053, -3.894737]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.326315789473684],"x":["-4.557895"],"y":[2.0]}},"id":"499bae3c-84da-4f5b-aa38-884180f909ae","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(6.715789, 8.042105]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(6.715789, 8.042105]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.3263157894736821],"x":["7.378947"],"y":[0.0]}},"id":"7a07a427-3624-4a51-9018-e6ad153550bb","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(13.347368, 14.673684]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(13.347368, 14.673684]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.3263157894736821],"x":["14.010525999999999"],"y":[0.0]}},"id":"84775dfc-b2ed-436a-b0b9-34b38a9c617b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"76277673-7f1e-465b-ba66-4d1ea3566278","type":"ColumnDataSource"},"glyph":{"id":"5a9e606d-f9c0-429f-8162-a10a4d1c3b36","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"1e2d7139-d46a-43d9-be5f-9288898811d1","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"931d276d-0c29-401d-a742-c3bc6890f7ac","type":"BoxAnnotation"},{"attributes":{"axis_label":"mpg ...

# %%
s = Scatter(data=test, x='rf', y='lr', color='origin',
            height=300, width=700,
            tools='hover, box_zoom, lasso_select, save, reset',
            title='Comapring model predictions',
            xlabel='Random Forest',
            ylabel='Linear Regression',
            tooltips = [
              ('Model', '@name'),
              ('MPG', '@mpg'),
              ('hp',  '@hp')
            ])

show(s)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fe56432a-2384-404d-8e14-e14fbbffc661"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fe56432a-2384-404d-8e14-e14fbbffc661");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fe56432a-2384-404d-8e14-e14fbbffc661");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fe56432a-2384-404d-8e14-e14fbbffc661' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ac08d060-24e4-4cbb-bfb8-43c559a84f8f":{"roots":{"references":[{"attributes":{},"id":"36b1432c-facb-4c19-8f5b-2f82ce423b1e","type":"BasicTicker"},{"attributes":{},"id":"5aed3c26-9cf5-46a0-9e7c-dc6b9d0dc325","type":"BasicTickFormatter"},{"attributes":{},"id":"780df99b-67ba-469b-8a8a-33b548fc46bc","type":"ToolEvents"},{"attributes":{"axis_label":"Random Forest","formatter":{"id":"8757eae8-b51d-492b-a941-8283737e5af2","type":"BasicTickFormatter"},"plot":{"id":"ec893346-6184-4e9e-a3a6-b1b8a98aef08","subtype":"Chart","type":"Plot"},"ticker":{"id":"36b1432c-facb-4c19-8f5b-2f82ce423b1e","type":"BasicTicker"}},"id":"323b58ed-e65d-4817-9a7c-ad6507895f86","type":"LinearAxis"},{"attributes":{"axis_label":"Linear Regression","formatter":{"id":"5aed3c26-9cf5-46a0-9e7c-dc6b9d0dc325","type":"BasicTickFormatter"},"plot":{"id":"ec893346-6184-4e9e-a3a6-b1b8a98aef08","subtype":"Chart","type":"Plot"},"ticker":{"id":"30204214-b3ce-4e21-afad-072c04d4a628","type":"BasicTicker"}},"id":"2c9c76f0-8b62-4abf-8af7-6edbfddaf600","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"1aa61d49-f1a0-48bf-9f40-48feac3d7c89","type":"PolyAnnotation"},{"attributes":{"items":[{"id":"193a152b-a76a-46c0-98c1-b965e2126e9d","type":"LegendItem"},{"id":"0a6b2503-508d-4769-b490-3cfb8234be71","type":"LegendItem"},{"id":"6e9d18f9-8657-48f0-9104-e81e01519894","type":"LegendItem"}],"location":"top_left","plot":{"id":"ec893346-6184-4e9e-a3a6-b1b8a98aef08","subtype":"Chart","type":"Plot"}},"id":"96014d06-2f59-4ab5-82aa-efc60cdb024d","type":"Legend"},{"attributes":{"label":{"value":"Asian"},"renderers":[{"id":"58a458ef-77dd-4067-a86a-60796133f8b4","type":"GlyphRenderer"}]},"id":"0a6b2503-508d-4769-b490-3cfb8234be71","type":"LegendItem"},{"attributes":{"callback":null,"plot":{"id":"ec893346-6184-4e9e-a3a6-b1b8a98aef08","subtype":"Chart","type":"Plot"}},"id":"f3f1bfac-498a-40f7-99ee-6649f7adbbef","type":"HoverTool"},{"attributes":{"callback":null,"overlay":{"id":"1aa61d49-f1a0-48bf-9f40-48feac3d7c89","type":"PolyAnnotation"},"plot":{"id":"ec893346-6184-4e9e-a3a6-b1b8a98aef08","subtype":"Chart","type":"Plot"}},"id":"4d9a3347-c1b9-4a17-8860-da0a72d21491","type":"LassoSelectTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"bf7eb742-63ff-4b33-8d5e-5514136276ed","type":"Circle"},{"attributes":{"label":{"value":"European"},"renderers":[{"id":"7678ceef-a8c6-4084-a4c6-d43b094e3d0c","type":"GlyphRenderer"}]},"id":"6e9d18f9-8657-48f0-9104-e81e01519894","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x_values","y_values","name","mpg","hp"],"data":{"chart_index":[{"origin":"European"},{"origin":"European"},{"origin":"European"},{"origin":"European"},{"origin":"European"},{"origin":"European"},{"origin":"European"},{"origin":"European"},{"origin":"European"},{"origin":"European"},{"origin":"European"},{"origin":"European"},{"origin":"European"},{"origin":"European"}],"hp":[125,81,110,76,98,60,112,77,87,133,62,103,115,115],"mpg":{"__ndarray__":"AAAAAAAAMUAAAAAAAAA5QAAAAAAAgDVAAAAAAADAREAAAAAAAAA2QAAAAAAAADtAAAAAAAAAMkBmZmZmZmY5QAAAAAAAADlAMzMzMzMzMEDNzMzMzMw9QM3MzMzMTDRAAAAAAAAAOUCamZmZmZk1QA==","dtype":"float64","shape":[14]},"name":["volvo 264gl","opel 1900","bmw 320i","vw rabbit","volvo 244dl","volkswagen model 111","volvo 145e (sw)","mercedes benz 300d","peugeot 504","peugeot 604sl","vokswagen rabbit","audi 5000","saab 99le","saab 99gle"],"origin":["European","European","European","European","European","European","European","European","European","European","European","European","European","European"],"x_values":{"__ndarray__":"AAAAAAAACMAAAAAAAAAAAAAAAAAAAATAAAAAAAAAI0 ...

# %% [markdown]
# Creating a stand-alone model
# ---------------------------
# This has all been done in a Jupyter Notebook, which is ideal for interactive and exploratory data science.  But the trained machine learning model often needs to be used in a stand-alone application or service.  In this case it is necessary to export the model and develop an independent model execution package.

# %%
model = linear_regression_regressor()
model.fit(train['cyl displ hp weight accel yr'.split()],
          train['mpg'].values.ravel())
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.externals.joblib import dump
dump(model,'mpg_linear_regression_model.pkl')
# Out:
# ['mpg_linear_regression_model.pkl']

# %%
# !ls -Fla mpg_linear_regression_model.pkl
# Out:
# -rw-r--r--  1 ijstokes  staff  673 Dec  7 22:48 mpg_linear_regression_model.pkl

# %% [markdown]
# Now to simulate a production operation environment we'll also export the test data.

# %%
test.to_csv('mpg_data.csv')

# %% [markdown]
# We can exercise this model on the data using these operations:

# %%
from sklearn.externals.joblib import load
import pandas as pd

mpg_model = load('mpg_linear_regression_model.pkl')
data      = pd.read_csv('mpg_data.csv')

# %%
# augment the mpg DataFrame with the prediction
data['prediction'] = mpg_model.predict(data['cyl displ hp weight accel yr'.split()])

# %%
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook, output_file

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cfc49702-9df9-4fd4-9c67-cbec9595b9b9">Loading BokehJS ...</span>
#     </div>

# %%
s = Scatter(data=data,
            x='mpg', y='prediction', color='origin',
            height=300, width=600,
            title='Fuel efficiency predictions of selected vehicles from 1970-1982',
            tools='hover, box_zoom, lasso_select, save, reset',
            tooltips = [
              ('model','@name'),
              ('HP',  '@hp'),
              ('actual MPG', '@mpg'),
              ('predicted MPG', '@prediction')
            ])

show(s)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="81e12bb1-d408-470a-b219-33ffc48764ba"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("81e12bb1-d408-470a-b219-33ffc48764ba");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("81e12bb1-d408-470a-b219-33ffc48764ba");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '81e12bb1-d408-470a-b219-33ffc48764ba' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"49de6735-162a-42ff-bc5e-6e474774e085":{"roots":{"references":[{"attributes":{},"id":"b7e440c9-3ba5-4365-8457-3c3b10232c4f","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"40cec380-29c7-4ab2-83c2-b418c0088f3f","type":"Circle"},{"attributes":{},"id":"d222cf0b-3aa4-4427-8e7b-21fdd6ba95a4","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"04fdcc14-513d-4683-a7bd-b3064b1ca2b3","type":"ColumnDataSource"},"glyph":{"id":"40cec380-29c7-4ab2-83c2-b418c0088f3f","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"4f6cc6a8-3332-48bf-8691-e57f6639a038","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"49621591-009d-4202-881d-86af4b208a20","type":"Circle"},{"attributes":{"callback":null,"column_names":["x_values","y_values","name","hp","mpg","prediction"],"data":{"chart_index":[{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"},{"origin":"Asian"}],"hp":[70,97,97,67,60,65,90,97,62,70,95,65,92],"mpg":{"__ndarray__":"MzMzMzOzQ0AAAAAAAAA4QDMzMzMzMztAzczMzMxMRkDNzMzMzIxBQAAAAAAAgEJAzczMzMzMPUAAAAAAAAA4QJqZmZmZ2UJAAAAAAAAAQEAAAAAAAAA5QAAAAAAAAD9AAAAAAACAQkA=","dtype":"float64","shape":[13]},"name":["datsun b210 gx","honda civic","datsun 510","honda civic 1500 gl","honda civic 1300","datsun 210 mpg","toyota corona liftback","datsun 710","toyota tercel","datsun b-210","toyota corona","toyota corolla 1200","datsun 510 hatchback"],"origin":["Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian","Asian"],"prediction":{"__ndarray__":"twXl6qBxP0CRDm+RvFQ5QNMItdzZ1z1AlGHOgFLMQECUGWN4KqVBQBqX3yi/REFAUQB6kUlfPEAJE6ruWh46QJgzulxHvEBA8bnGff0dPkBbemwBfZc4QE05YE3y9ztAK9xu4mpaPkA=","dtype":"float64","shape":[13]},"x_values":{"__ndarray__":"MzMzMzOzQ0AAAAAAAAA4QDMzMzMzMztAzczMzMxMRkDNzMzMzIxBQAAAAAAAgEJAzczMzMzMPUAAAAAAAAA4QJqZmZmZ2UJAAAAAAAAAQEAAAAAAAAA5QAAAAAAAAD9AAAAAAACAQkA=","dtype":"float64","shape":[13]},"y_values":{"__ndarray__":"twXl6qBxP0CRDm+RvFQ5QNMItdzZ1z1AlGHOgFLMQECUGWN4KqVBQBqX3yi/REFAUQB6kUlfPEAJE6ruWh46QJgzulxHvEBA8bnGff0dPkBbemwBfZc4QE05YE3y9ztAK9xu4mpaPkA=","dtype":"float64","shape":[13]}}},"id":"04fdcc14-513d-4683-a7bd-b3064b1ca2b3","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"cb97ce34-8e15-467a-a38c-783cc366ba64","subtype":"Chart","type":"Plot"},"ticker":{"id":"83e07b2f-339d-4b10-ad1e-1eed48a451ae","type":"BasicTicker"}},"id":"4f08b473-814e-4e4d-9a39-73fed01dc59a","type":"Grid"},{"attributes":{"callback":null,"plot":{"id":"cb97ce34-8e15-467a-a38c-783cc366ba64","subtype":"Chart","type":"Plot"},"tooltips":[["model","@name"],["HP","@hp"],["actual MPG","@mpg"],["predicted MPG","@prediction"]]},"id":"20cdbe55-8680-4a61-82ea-b8213443569d","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values","name","hp","mpg","prediction"],"data":{"chart_index":[{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origin":"American"},{"origi ...

# %% [markdown]
# Anaconda Project Data Science App
# -------------------------------
# **NOTE:** The files below can be found [in this gist](https://gist.github.com/ijstokes/87cd5477cc76a63473eaeaaf8ff55047)

# %% [markdown]
# This is the `anaconda-project.yml` file that defines the MPG prediction app:
#
# ```yaml
# name: mpg_prediction
# description: Predict MPG using a linear regression model
#
# commands:
#   default:
#     bokeh_app: .
#
# packages:
#   - bokeh=0.12.5=py36_1
#   - pandas=0.20.1=np112py36_0
#   - scikit-learn=0.18.1=np112py36_1
# ```

# %% [markdown]
# This is the `main.py` file that provides the Bokeh app:
#
# ```python
# import pandas as pd
#
# from sklearn.externals.joblib import load
#
# from bokeh.charts import Scatter
# from bokeh.io import curdoc, show, output_notebook, output_file
#
# mpg_model = load('mpg_linear_regression_model.pkl')
# data      = pd.read_csv('mpg_data.csv')
#
# # augment the mpg DataFrame with the prediction
# data['prediction'] = mpg_model.predict(data['cyl displ hp weight accel yr'.split()])
#
# s1 = Scatter(data=data,
#             x='mpg', y='prediction', color='origin',
#             height=300, width=600,
#             title='Fuel efficiency predictions of selected vehicles from 1970-1982',
#             tools='hover, box_zoom, lasso_select, save, reset',
#             tooltips = [
#               ('model','@name'),
#               ('HP',  '@hp'),
#               ('actual MPG', '@mpg'),
#               ('predicted MPG', '@prediction')
#             ])
#
# s2 = Scatter(data=data,
#             x='yr', y='mpg', color='origin',
#             height=300, width=600,
#             title='Fuel efficiency of selected vehicles from 1970-1982',
#             tools='hover, box_zoom, save, reset',
#             tooltips = [
#               ('model','@name'),
#               ('HP',  '@hp'),
#               ('cyl', '@cyl'),
#               ('weight', '@weight')
#             ])
#
# curdoc().add_root(s1)
# curdoc().add_root(s2)
# curdoc().title = "MPG Prediction"
# ```

# %% [markdown]
# Save these two files into a directory that *also* contains `mpg_data.csv` and `mpg_linear_regression_model.pkl`.  Then the projects can be executed using one of these two options:
#
# * `anaconda-project run`
# * `bokeh serve .`

# %% [markdown]
# Summary
# =======
# In this demonstration we explored a simple data analysis workflow and made use of three of the most popular packages in your Anaconda Open Data Science tool box:
#
# * Pandas for data import and processing
# * Bokeh for data visualization
# * Scikit-Learn for machine learning and predictive modeling

# %% [markdown]
# Go Further
# ==========
# 1. Run this notebook one cell at a time (by pressing CTRL-ENTER) and try experimenting with parameters. Interact with the visualizations.
#
# 2. Modify the scatter plot to examine different dimensions, such as *Year* vs. *Horsepower*, or *Displacement* vs. *Horsepower*.
#
# 3. Modify which features the `HoverTool` displays.
#
# 4. Try training the model with fewer features (e.g. try just *Displacement* and *Weight*) -- remember that when you exercise it to generate predictions you can only provide those features.
#
# 5. Try using the *K-Nearest Neighbor* or *Support Vector Classifier*.
